# %% [markdown]
# # Phase 1: Tropical Cyclone Damage Assesment

# %% [markdown]
# ## Challenge Phase 1 Overview

# %% [markdown]
# <div align="justify">Welcome to the EY Open Science Data Challenge 2024 ! This challenge consists of two phases – Phase 1 and Phase 2. In Phase 1 of the challenge, participants will be provided with high-resolution pre and post event satellite images from Maxar GeoEye-1 of an area impacted by tropical cyclone, as well as moderate-resolution data from the European Sentinel-2 (optical) and Landsat (Optical) satellites. Participants will have to develop a machine learning model to identify and detect “damaged” and “un-damaged” coastal infrastructure (residential and commercial buildings), which get impacted by natural calamities like hurricanes, cyclones, etc.
# </div>

# %% [markdown]
# <b>Challenge Aim: </b><p align="justify"> <p>

# %% [markdown]
# <p align="justify">
# Participants will have to build a machine learning model, which can identify and detect the following objects in a satellite image of a cyclone impacted area:
# <li>Undamaged Residential Building</li>
# <li>Damaged Residential Building</li>
# <li>Undamaged Commercial Building</li>
# <li>Damaged Commercial Building</li>
# </p>
#
# <div align="justify">In this notebook, we will demonstrate a basic model workflow that can serve as a starting point for the challenge. The basic model has been built to identify and detect "damaged" and "un-damaged" residential as well as commercial buildings. In this demonstration, we have used only the post event images from the Maxar GeoEye-1, and trained a object detection model using <a href = https://docs.ultralytics.com/>YOLOv8.</a> <div>
#
# <div align="justify"> Please note that this notebook is just a starting point. We have made many assumptions in this notebook that you may think are not best for solving the challenge effectively. You are encouraged to modify these functions, rewrite them, or try an entirely new approach.</div>

# %% [markdown]
# ## Load In Dependencies

# %% [markdown]
# To run this demonstration notebook, you will need to have the following packages imported below installed. This may take some time.

# %% [markdown]
# Run the below cell to install the packages. Note that this cell needs to be run only once.

# %%
### Run this cell only once.
# %pip install ultralytics
# !pip install opencv-python-headless
# !pip install labelme2yolo
# Out:
# Collecting ultralytics
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/8e/a3/de0a9cc2cdd735204347fd30265240f6ea0679c347530e4c864100e34544/ultralytics-8.1.13-py3-none-any.whl.metadata
#   Downloading ultralytics-8.1.13-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.2 kB ? eta -:--:--
#      ------------------- ------------------ 20.5/40.2 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 40.2/40.2 kB 967.1 kB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in t:\deeplearning\lib\site-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in t:\deeplearning\lib\site-packages (from ultralytics) (1.23.1)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Obtaining dependency information for opencv-python>=4.6.0 from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in t:\deeplearning\lib\site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in t:\deeplearning\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in t:\deeplearning\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in t:\deeplearning\lib\site-packages (from ultralytics) (1.11.1)
# Requirement already satisfied: torch>=1.8.0 in t:\deeplearning\lib\site-packages (from ultralytics) (2.0.1)
# Requirement already satisfied: torchvision>=0.9.0 in t:\deeplearning\lib\site-packages (from ultralytics) (0.15.2)
# Requirement already satisfied: tqdm>=4.64.0 in t:\deeplearning\lib\site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in t:\deeplearning\lib\site-packages (from ultralytics) (5.9.0)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in t:\deeplearning\lib\site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in t:\deeplearning\lib\site-packages (from ultralytics) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in t:\deeplearning\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in t:\deeplearning\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in t:\deeplearning\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in t:\deeplearning\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in t:\deeplearning\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in t:\deeplearning\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in t:\deeplearning\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in t:\deeplearning\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (6.0.1)
# Requirement already satisfied: pytz>=2020.1 in t:\deeplearning\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in t:\deeplearning\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in t:\deeplearning\lib\site-packages (from requests>=2.23.0->ultralytics) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in t:\deeplearning\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in t:\deeplearning\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in t:\deeplearning\lib\site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in t:\deeplearning\lib\site-packages (from torch>=1.8.0->ultralytics) (3.9.0)
# Requirement already satisfied: typing-extensions in t:\deeplearning\lib\site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in t:\deeplearning\lib\site-packages (from torch>=1.8.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in t:\deeplearning\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in t:\deeplearning\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: colorama in t:\deeplearning\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in t:\deeplearning\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.16.2)
# Requirement already satisfied: six>=1.5 in t:\deeplearning\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in t:\deeplearning\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in t:\deeplearning\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.1.13-py3-none-any.whl (710 kB)
#    ---------------------------------------- 0.0/710.2 kB ? eta -:--:--
#    ----------------- ---------------------- 317.4/710.2 kB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 710.2/710.2 kB 9.0 MB/s eta 0:00:00
# Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.6 MB 26.4 MB/s eta 0:00:02
#    -- ------------------------------------- 2.0/38.6 MB 21.7 MB/s eta 0:00:02
#    --- ------------------------------------ 3.8/38.6 MB 27.1 MB/s eta 0:00:02
#    ------ --------------------------------- 6.3/38.6 MB 36.5 MB/s eta 0:00:01
#    ------ --------------------------------- 6.5/38.6 MB 27.4 MB/s eta 0:00:02
#    --------- ------------------------------ 9.4/38.6 MB 33.5 MB/s eta 0:00:01
#    ------------ --------------------------- 12.2/38.6 MB 43.5 MB/s eta 0:00:01
#    --------------- ------------------------ 14.8/38.6 MB 46.7 MB/s eta 0:00:01
#    ------------------ --------------------- 18.2/38.6 MB 65.6 MB/s eta 0:00:01
#    --------------------- ------------------ 21.2/38.6 MB 65.6 MB/s eta 0:00:01
#    ------------------------- -------------- 24.2/38.6 MB 65.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.2/38.6 MB 65.6 MB/s eta 0:00:01
#    ------------------------------- -------- 30.2/38.6 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.2/38.6 MB 65.6 MB/s eta 0:00:01
#    ------------------------------------- -- 36.2/38.6 MB 65.2 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 65.2 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 65.2 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 65.2 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 36.3 MB/s eta 0:00:00
# Installing collected packages: py-cpuinfo, opencv-python, thop, ultralytics
# Successfully installed opencv-python-4.9.0.80 py-cpuinfo-9.0.0 thop-0.1.1.post2209072238 ultralytics-8.1.13
# Note: you may need to restart the kernel to use updated packages.
# Collecting opencv-python-headless
#   Obtaining dependency information for opencv-python-headless from https://files.pythonhosted.org/packages/20/44/458a0a135866f5e08266566b32ad9a182a7a059a894effe6c41a9c841ff1/opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
#   Downloading opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17.0 in t:\deeplearning\lib\site-packages (from opencv-python-headless) (1.23.1)
# Downloading opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB 10.6 MB/s eta 0:00:04
#    - -------------------------------------- 1.4/38.5 MB 17.3 MB/s eta 0:00:03
#    --- ------------------------------------ 3.1/38.5 MB 24.3 MB/s eta 0:00:02
#    ------ --------------------------------- 5.8/38.5 MB 33.9 MB/s eta 0:00:01
#    --------- ------------------------------ 8.8/38.5 MB 40.3 MB/s eta 0:00:01
#    ------------ --------------------------- 11.8/38.5 MB 59.5 MB/s eta 0:00:01
#    --------------- ------------------------ 14.8/38.5 MB 65.6 MB/s eta 0:00:01
#    ------------------ --------------------- 17.9/38.5 MB 65.6 MB/s eta 0:00:01
#    --------------------- ------------------ 20.9/38.5 MB 65.6 MB/s eta 0:00:01
#    ------------------------ --------------- 23.8/38.5 MB 65.6 MB/s eta 0:00:01
#    --------------------------- ------------ 26.9/38.5 MB 59.5 MB/s eta 0:00:01
#    ------------------------------- -------- 30.0/38.5 MB 59.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.9/38.5 MB 59.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.0/38.5 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 34.4 MB/s eta 0:00:00
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.9.0.80
# Collecting labelme2yolo
#   Obtaining dependency information for labelme2yolo from https://files.pythonhosted.org/packages/4c/b9/129fc5fc8b23c875db11b9e3fbe743ad77f1d31d64a8fb3c3ee1ab92b89c/labelme2yolo-0.1.4-py3-none-any.whl.metadata
#   Downloading labelme2yolo-0.1.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: numpy<1.27.0,>=1.23.1 in t:\deeplearning\lib\site-packages (from labelme2yolo) (1.23.1)
# Requirement already satisfied: opencv-python>=4.1.2 in t:\deeplearning\lib\site-packages (from labelme2yolo) (4.9.0.80)
# Requirement already satisfied: pillow<10.3,>=9.2 in t:\deeplearning\lib\site-packages (from labelme2yolo) (9.4.0)
# Downloading labelme2yolo-0.1.4-py3-none-any.whl (8.6 kB)
# Installing collected packages: labelme2yolo
# Successfully installed labelme2yolo-0.1.4

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in t:\deeplearning\lib\site-packages (1.3.9)
# Requirement already satisfied: affine in t:\deeplearning\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in t:\deeplearning\lib\site-packages (from rasterio) (23.1.0)
# Requirement already satisfied: certifi in t:\deeplearning\lib\site-packages (from rasterio) (2023.7.22)
# Requirement already satisfied: click>=4.0 in t:\deeplearning\lib\site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in t:\deeplearning\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in t:\deeplearning\lib\site-packages (from rasterio) (1.23.1)
# Requirement already satisfied: snuggs>=1.4.1 in t:\deeplearning\lib\site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in t:\deeplearning\lib\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in t:\deeplearning\lib\site-packages (from rasterio) (68.0.0)
# Requirement already satisfied: colorama in t:\deeplearning\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: pyparsing>=2.1.6 in t:\deeplearning\lib\site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# ^C

# %% [markdown]
# # NOTE FROM SHAW: INSTALLING GDAL FOR OSGEO IS A LITTLE TRICKY
#
# ## 1. First, download the GDAL wheel file from the following link: https://github.com/cgohlke/geospatial-wheels/releases
# ## 2. Put the extracted wheel file in the directory called "wheels" in the root of the project
# ## 3. Make sure there isnt a wheel file in the directory called "wheels" in the root of the project already
# ## 2. Then, run the following command to install the wheel file: `pip install path_to_wheel_file`
# ## 3. Make sure you pick the wheel that corresponds to your python version and system architecture.
#
# ## For example, if you are using Python 3.8 on a 64-bit system, you would run the following command: `pip install GDAL-3.3.0-cp38-cp38-win_amd64.whl`

# %%
# !pip install T:\EY_Challenge\EY_Challenge\wheels\GDAL-3.8.2-cp39-cp39-win_amd64.whl
# Out:
# Processing t:\ey_challenge\ey_challenge\wheels\gdal-3.8.2-cp39-cp39-win_amd64.whl
# Installing collected packages: GDAL
# Successfully installed GDAL-3.8.2

# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# GeoTiff Images
import rasterio
from osgeo import gdal

# Visualisation
from matplotlib import pyplot as plt
import matplotlib.image as img
from matplotlib.pyplot import figure
from PIL import Image

# Model Building
import ultralytics
from ultralytics import YOLO
import labelme2yolo

# Others
import os
import shutil
import zipfile

# %matplotlib inline

# %% [markdown]
# ## Importing the Data

# %% [markdown]
# <div align="justify">Before building the model, we need to load both Pre-Event and Post Event GeoTiFF Images. We have curated for you data from a certain region in San Juan, Puerto Rico for the year 2017. The variables <b><i>pre_event_image</b></i> and <b><i>post_event_image</b></i> will have the path to both of these images. Consider that the images are considerably large and might require some time to load. The image named Pre_Event_San_Juan.tif is pre event image and is sized at 969 MB, while the image named as Post_Event_San_Juan.tif is post event image and sized at 1.2 GB.</div><br>
#
# <div align ="justify">To download the images please visit the <a href = "https://challenge.ey.com/challenges/tropical-cyclone-damage-assessment-lnucmbo5"><b>data description</b></a> section of the challenge portal or participants can use the wget command to download the files in the background. Wget is the non-interactive network downloader which is used to download files from the server even when the user has not logged on to the system and it can work in the background without hindering the current process. </div>

# %%
# !wget https://challenge.ey.com/api/v1/storage/admin-files/Pre_Event_San_Juan.tif -O ../Datasets/Pre_Event_San_Juan.tif

# %%
# !wget https://challenge.ey.com/api/v1/storage/admin-files/Post_Event_San_Juan.tif -O ../Datasets/Post_Event_San_Juan.tif

# %%
import os

print(os.getcwd())
print(os.listdir('.'))
# Out:
# t:\EY_Challenge\EY_Challenge\Sample Notebooks
# ['Challenge_2024_Landsat_NDVI.ipynb', 'Challenge_2024_S2_NDVI.ipynb', 'Phase-1 Benchmark Notebook 2024 V0.5 1.ipynb', 'README.md']

# %%
pre_event_image = '../Datasets/Pre_Event_San_Juan.tif'
post_event_image = '../Datasets/Post_Event_San_Juan.tif'

# %% [markdown]
# #### What are GeoTIFF Images ?
#
# <div align = "justify">The GeoTIFF format is a metadata standard openly available to the public, which permits the incorporation of georeferencing data into a TIFF file. Extra possible information like map projection, coordinate systems, ellipsoids, datums, and all other required elements for setting the specific spatial reference for the file can be included. The GeoTIFF format is completely aligned with TIFF 6.0, hence, even if a software is unable to read and understand the distinctive metadata, it can still operate a GeoTIFF format file.</div>

# %% [markdown]
# #### Maxar GeoEye-1 Panchromatic Images
#
# <div align = "justify">Maxar’s visual panchromatic band is a unique high-resolution product that applies RGB (red, green, blue) spectral information to a grey-scale panchromatic image at 30-cm resolution. No cloud masking has been provided with the dataset, so users should be cautious with the data as there are clouds in each of the images. A careful review of the RGB bands (see below) shows the clouds as saturated (dark) regions in each color band. You will find that the pre-storm image has far more clouds (mostly lower left) than the post-storm image (mostly upper portion).</div><br>
#
# <div align = "justify">If you face kernel crash issue, while visualizing the images on notebook, you can visualize the images on <a href = "https://qgis.org/en/site/"><b>QGIS</b></a>, which is a free and open source Geographic Information System.</div>

# %% [markdown]
# ## Visualising GeoTiFF Images

# %%
# Open the geotiff file
def load_and_visualize(image_path):
    with rasterio.open(image_path) as src:
        # read the red, green and blue bands
        red = src.read(1)
        green = src.read(2)
        blue = src.read(3)
    # Plot the bands
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 5))
    ax1.imshow(red,cmap='Reds')
    ax1.set_title('Red Band')
    ax2.imshow(green, cmap='Greens')
    ax2.set_title('Green Band')
    ax3.imshow(blue, cmap='Blues')
    ax3.set_title('Blue Band')
plt.show()

# %%
load_and_visualize(pre_event_image)

# %%
load_and_visualize(post_event_image)

# %% [markdown]
# ## Data Pre Processing

# %% [markdown]
# <div align="justify">Now that our data is loaded , we can we see that the area is quite huge, processing this is a very difficult task. Since in this demonstration, we are using only post-event image to create training dataset, let us proceed to create grids for the post-event images, this facilitates the processing of GeoTiFF image, and these grids will be saved in a specified directory. We create these grids using a function named <i><b>generate_tiles</b></i>. This function takes a .tiff image and the grid size, then transforms them into grids. In this specific case, we've made grids measuring 512x512. But, you can explore the options of creating smaller and/or larger grid as well. Smaller and larger grids have its own pros and cons. You should do a tradeoff between grid size and labelling effort.</div>
#
# <p><b>Note:</b> This process may take few minutes to generate the grids.</p>

# %% [markdown]
# <h4 style="color:rgb(195, 52, 235)"><strong>Tip 1</strong></h4>
# <div align="justify">In this case, we're working under the assumption that images taken after the event will also contain infrastructure that hasn't been damaged. To amplify the number of undamaged infrastructure instances, participants may include pre event images as well to increase the training data size.</div>

# %%
def generate_tiles(input_file, output_dir,grid_x,grid_y):
    ds = gdal.Open(input_file)

    # Get image size and number of bands
    width = ds.RasterXSize
    height = ds.RasterYSize
    num_bands = ds.RasterCount

    # Calculate number of tiles in each dimension
    num_tiles_x = (width // grid_x)
    num_tiles_y = (height // grid_y)

    print(f"Total number of tiles: {num_tiles_x * num_tiles_y}")

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Iterate over each tile and save as a separate TIFF image
    for i in range(num_tiles_x):
        for j in range(num_tiles_y):
            x_offset = i *  grid_x
            y_offset = j *  grid_y

            tile_width = min(grid_x, width - x_offset)
            tile_height = min(grid_y, height - y_offset)

            tile = []
            for band in range(1, num_bands + 1):
                tile_data = ds.GetRasterBand(band).ReadAsArray(x_offset, y_offset, tile_width, tile_height)
                tile.append(tile_data)

            # Create output filename
            output_file = os.path.join(output_dir, f"tile_{i}_{j}.tif")
                
            # Create an output TIFF file with same CRS and band values range
            driver = gdal.GetDriverByName("GTiff")
            options = ['COMPRESS=DEFLATE', 'PREDICTOR=2', 'TILED=YES']
            out_ds = driver.Create(output_file, tile_width, tile_height, num_bands, 
                       ds.GetRasterBand(1).DataType, options=options)
            # out_ds = driver.Create(output_file, tile_width, tile_height, num_bands, ds.GetRasterBand(1).DataType)

            # Set the geotransform
            geotransform = list(ds.GetGeoTransform())
            geotransform[0] = geotransform[0] + x_offset * geotransform[1]
            geotransform[3] = geotransform[3] + y_offset * geotransform[5]
            out_ds.SetGeoTransform(tuple(geotransform))

            # Set the projection
            out_ds.SetProjection(ds.GetProjection())

            # Write each band to the output file
            for band in range(1, num_bands + 1):
                out_band = out_ds.GetRasterBand(band)
                out_band.WriteArray(tile[band - 1])

            # Close the output file
            out_ds = None

    print("Tiles generation completed.")

# %%
input_file = '../Datasets/Post_Event_San_Juan.tif'
output_dir = "../Post_Event_Grids_In_TIFF"
grid_x = 512
grid_y = 512
generate_tiles(input_file, output_dir,grid_x,grid_y)
# Out:
# Total number of tiles: 10730
# Tiles generation completed.

# %% [markdown]
# ## Annotating the Images

# %% [markdown]
# <div align ="justify">Image annotation is the process of labelling images in a given dataset to train machine learning models. When the manual annotation is completed, labelled images are processed by a machine learning or deep learning model to replicate the annotations without human supervision. Image annotation sets the standards, which the model tries to copy, so any error in the labels is replicated too. Therefore, precise image annotation lays the foundation for neural networks to be trained, making annotation one of the most important tasks in computer vision.</div>

# %% [markdown]
# <div align="justify">Inorder to annotate images, we will convert them to .jpg images as majority of the annotaiton tools do not support .tif format. There are many open source annotation tools available. Participants can choose any of the annotation tools. Here a list of few annotation tools that participants can use:</div>
# <ul>
#     <li>LabelMe</li>
#     <li>VGG Image Annotator</li>
#     <li>LabelImg</li>
# </ul>

# %% [markdown]
# <h4 style="color:rgb(195, 52, 235)"><strong>Tip 2</strong></h4>
# <div align="justify">Each annotation instrument provides a unique image annotation file format. Choose the annotation tool depending on the model you plan to construct. Also, note that numerous supplementary scripts exist that assist in converting one kind of image annotation file into another.</div>

# %% [markdown]
# <div align='justify'>In this demonstration notebook, we will be using <a href = "https://pypi.org/project/labelme/">LabelMe</a> to annotate the images. Since LabelMe does not support .Tiff format we will convert these grids to .jpg/.png format.</div>

# %% [markdown]
# ### Identifying Damaged and Undamged Infrastructure

# %% [markdown]
# <div align= "justify">Commercial structures often have larger rooftops and typically have parking areas. In contrast, residential buildings generally have more limited roof space. Buildings deemed as damaged often exhibit roof impairments, while those classified as undamaged have no visible damages. To further grasp the distinctions between damaged and undamaged buildings in both commercial and residential categories, please refer the <a href = "https://challenge.ey.com/api/v1/storage/admin-files/2513955341204317-65bb9169868dc8fadbfc9728-2024%20EY%20Open%20Science%20Data%20Challenge%20Participant%20Guidance.pdf">guidance document</a>. The document is designed to provide a more detailed and comprehensive understanding of these topics.</div>

# %% [markdown]
# <div align = "justify">In conclusion, it is safe to assert that the most challenging aspect of the entire model-building task is discerning between residential and commercial structures and the pinpointing of damaged building. </div>

# %% [markdown]
# ### Converting Images to .png/.jpg images

# %% [markdown]
# <div align="justify">Since our annotation tool requires images to be in .jpg/.png format, let's proceed to convert the grids from .tiff format to .jpg format, this facilitates the processing of GeoTiFF image, and these grids in .jpg/.png will be saved in a specified directory. We convert these grids using a function named <i><b>convert_tiff_to_jpeg</b></i>.This function takes the folder with .tiff image as input and the output directory path, where these converted images need to be saved.</div>

# %%
def convert_tiff_to_jpeg(input_dir,output_dir):
    # check if output_dir exists, if not create it
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for filename in os.listdir(input_dir):
        # check if file is an image (ends with .tif)
        if filename.endswith('.tif'):
            img = Image.open(os.path.join(input_dir, filename))
        
            # check if image is RGB mode, if not convert it
            if img.mode != 'RGB':
                img = img.convert('RGB')
        
            # create new filename, replace .tif with .jpg
            output_filename = os.path.splitext(filename)[0] + '.jpg'
        
            # save the image in JPEG format
            print(os.path.join(output_dir, output_filename))
            img.save(os.path.join(output_dir, output_filename), 'JPEG')
    print("Conversion from TIFF to JPEG completed.")

# %%
# specify directory
input_dir = '../Post_Event_Grids_In_TIFF'
output_dir = '../Post_Event_Grids_In_JPEG'
convert_tiff_to_jpeg(input_dir,output_dir)
# Out:
# ../Post_Event_Grids_In_JPEG\tile_0_0.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_1.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_10.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_100.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_101.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_102.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_103.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_104.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_105.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_106.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_107.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_108.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_109.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_11.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_110.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_111.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_112.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_113.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_114.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_115.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_116.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_117.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_118.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_119.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_12.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_120.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_121.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_122.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_123.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_124.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_125.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_126.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_127.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_128.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_129.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_13.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_130.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_131.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_132.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_133.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_134.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_135.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_136.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_137.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_138.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_139.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_14.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_140.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_141.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_142.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_143.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_144.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_15.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_16.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_17.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_18.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_19.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_56.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_57.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_58.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_59.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_6.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_60.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_61.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_62.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_63.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_64.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_65.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_66.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_67.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_68.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_69.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_7.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_70.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_71.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_72.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_73.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_74.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_75.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_76.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_77.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_78.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_79.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_8.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_80.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_81.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_82.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_83.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_84.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_85.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_86.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_87.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_88.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_89.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_9.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_90.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_91.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_92.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_93.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_94.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_95.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_96.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_97.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_98.jpg
# ../Post_Event_Grids_In_JPEG\tile_0_99.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_0.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_1.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_10.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_100.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_101.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_102.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_103.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_104.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_105.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_106.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_107.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_108.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_109.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_11.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_110.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_111.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_112.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_113.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_114.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_115.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_116.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_117.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_118.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_119.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_12.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_120.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_121.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_122.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_123.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_124.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_125.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_126.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_127.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_128.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_129.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_13.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_130.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_131.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_132.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_133.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_134.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_135.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_136.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_137.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_138.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_139.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_14.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_140.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_141.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_142.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_143.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_144.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_15.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_16.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_17.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_18.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_19.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_56.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_57.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_58.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_59.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_6.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_60.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_61.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_62.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_63.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_64.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_65.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_66.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_67.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_68.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_69.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_7.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_70.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_71.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_72.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_73.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_74.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_75.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_76.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_77.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_78.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_79.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_8.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_80.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_81.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_82.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_83.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_84.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_85.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_86.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_87.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_88.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_89.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_9.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_90.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_91.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_92.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_93.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_94.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_95.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_96.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_97.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_98.jpg
# ../Post_Event_Grids_In_JPEG\tile_10_99.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_0.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_1.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_10.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_100.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_101.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_102.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_103.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_104.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_105.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_106.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_107.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_108.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_109.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_11.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_110.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_111.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_112.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_113.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_114.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_115.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_116.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_117.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_118.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_119.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_12.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_120.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_121.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_122.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_123.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_124.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_125.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_126.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_127.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_128.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_129.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_13.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_130.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_131.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_132.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_133.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_134.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_135.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_136.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_137.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_138.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_139.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_14.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_140.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_141.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_142.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_143.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_144.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_15.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_16.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_17.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_18.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_19.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_56.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_57.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_58.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_59.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_6.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_60.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_61.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_62.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_63.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_64.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_65.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_66.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_67.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_68.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_69.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_7.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_70.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_71.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_72.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_73.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_74.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_75.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_76.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_77.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_78.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_79.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_8.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_80.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_81.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_82.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_83.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_84.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_85.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_86.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_87.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_88.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_89.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_9.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_90.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_91.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_92.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_93.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_94.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_95.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_96.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_97.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_98.jpg
# ../Post_Event_Grids_In_JPEG\tile_11_99.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_0.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_1.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_10.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_100.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_101.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_102.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_103.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_104.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_105.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_106.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_107.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_108.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_109.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_11.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_110.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_111.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_112.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_113.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_114.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_115.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_116.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_117.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_118.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_119.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_12.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_120.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_121.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_122.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_123.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_124.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_125.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_126.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_127.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_128.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_129.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_13.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_130.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_131.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_132.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_133.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_134.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_135.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_136.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_137.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_138.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_139.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_14.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_140.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_141.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_142.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_143.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_144.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_15.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_16.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_17.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_18.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_19.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_56.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_57.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_58.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_59.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_6.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_60.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_61.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_62.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_63.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_64.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_65.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_66.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_67.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_68.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_69.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_7.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_70.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_71.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_72.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_73.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_74.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_75.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_76.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_77.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_78.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_79.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_8.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_80.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_81.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_82.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_83.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_84.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_85.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_86.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_87.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_88.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_89.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_9.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_90.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_91.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_92.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_93.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_94.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_95.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_96.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_97.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_98.jpg
# ../Post_Event_Grids_In_JPEG\tile_12_99.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_0.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_1.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_10.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_100.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_101.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_102.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_103.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_104.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_105.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_106.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_107.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_108.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_109.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_11.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_110.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_111.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_112.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_113.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_114.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_115.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_116.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_117.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_118.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_119.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_12.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_120.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_121.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_122.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_123.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_124.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_125.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_126.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_127.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_128.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_129.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_13.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_130.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_131.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_132.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_133.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_134.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_135.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_136.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_137.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_138.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_139.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_14.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_140.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_141.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_142.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_143.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_144.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_15.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_16.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_17.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_18.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_19.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_56.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_57.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_58.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_59.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_6.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_60.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_61.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_62.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_63.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_64.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_65.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_66.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_67.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_68.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_69.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_7.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_70.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_71.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_72.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_73.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_74.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_75.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_76.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_77.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_78.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_79.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_8.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_80.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_81.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_82.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_83.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_84.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_85.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_86.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_87.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_88.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_89.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_9.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_90.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_91.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_92.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_93.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_94.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_95.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_96.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_97.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_98.jpg
# ../Post_Event_Grids_In_JPEG\tile_13_99.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_0.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_1.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_10.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_100.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_101.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_102.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_103.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_104.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_105.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_106.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_107.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_108.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_109.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_11.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_110.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_111.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_112.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_113.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_114.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_115.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_116.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_117.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_118.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_119.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_12.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_120.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_121.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_122.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_123.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_124.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_125.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_126.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_127.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_128.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_129.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_13.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_130.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_131.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_132.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_133.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_134.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_135.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_136.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_137.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_138.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_139.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_14.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_140.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_141.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_142.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_143.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_144.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_15.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_16.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_17.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_18.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_19.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_56.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_57.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_58.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_59.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_6.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_60.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_61.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_62.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_63.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_64.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_65.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_66.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_67.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_68.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_69.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_7.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_70.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_71.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_72.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_73.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_74.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_75.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_76.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_77.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_78.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_79.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_8.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_80.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_81.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_82.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_83.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_84.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_85.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_86.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_87.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_88.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_89.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_9.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_90.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_91.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_92.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_93.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_94.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_95.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_96.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_97.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_98.jpg
# ../Post_Event_Grids_In_JPEG\tile_14_99.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_0.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_1.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_10.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_100.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_101.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_102.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_103.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_104.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_105.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_106.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_107.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_108.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_109.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_11.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_110.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_111.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_112.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_113.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_114.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_115.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_116.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_117.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_118.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_119.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_12.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_120.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_121.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_122.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_123.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_124.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_125.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_126.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_127.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_128.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_129.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_13.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_130.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_131.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_132.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_133.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_134.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_135.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_136.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_137.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_138.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_139.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_14.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_140.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_141.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_142.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_143.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_144.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_15.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_16.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_17.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_18.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_19.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_56.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_57.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_58.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_59.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_6.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_60.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_61.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_62.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_63.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_64.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_65.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_66.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_67.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_68.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_69.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_7.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_70.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_71.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_72.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_73.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_74.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_75.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_76.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_77.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_78.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_79.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_8.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_80.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_81.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_82.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_83.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_84.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_85.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_86.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_87.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_88.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_89.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_9.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_90.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_91.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_92.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_93.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_94.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_95.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_96.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_97.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_98.jpg
# ../Post_Event_Grids_In_JPEG\tile_15_99.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_0.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_1.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_10.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_100.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_101.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_102.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_103.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_104.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_105.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_106.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_107.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_108.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_109.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_11.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_110.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_111.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_112.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_113.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_114.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_115.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_116.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_117.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_118.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_119.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_12.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_120.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_121.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_122.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_123.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_124.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_125.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_126.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_127.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_128.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_129.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_13.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_130.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_131.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_132.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_133.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_134.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_135.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_136.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_137.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_138.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_139.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_14.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_140.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_141.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_142.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_143.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_144.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_15.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_16.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_17.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_18.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_19.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_16_56.jpg
# ...
# ../Post_Event_Grids_In_JPEG\tile_7_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_56.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_57.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_58.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_59.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_6.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_60.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_61.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_62.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_63.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_64.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_65.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_66.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_67.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_68.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_69.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_7.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_70.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_71.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_72.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_73.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_74.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_75.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_76.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_77.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_78.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_79.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_8.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_80.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_81.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_82.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_83.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_84.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_85.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_86.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_87.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_88.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_89.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_9.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_90.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_91.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_92.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_93.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_94.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_95.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_96.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_97.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_98.jpg
# ../Post_Event_Grids_In_JPEG\tile_7_99.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_0.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_1.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_10.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_100.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_101.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_102.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_103.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_104.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_105.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_106.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_107.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_108.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_109.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_11.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_110.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_111.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_112.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_113.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_114.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_115.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_116.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_117.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_118.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_119.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_12.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_120.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_121.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_122.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_123.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_124.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_125.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_126.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_127.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_128.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_129.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_13.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_130.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_131.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_132.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_133.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_134.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_135.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_136.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_137.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_138.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_139.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_14.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_140.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_141.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_142.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_143.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_144.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_15.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_16.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_17.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_18.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_19.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_56.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_57.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_58.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_59.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_6.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_60.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_61.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_62.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_63.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_64.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_65.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_66.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_67.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_68.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_69.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_7.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_70.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_71.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_72.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_73.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_74.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_75.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_76.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_77.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_78.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_79.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_8.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_80.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_81.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_82.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_83.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_84.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_85.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_86.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_87.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_88.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_89.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_9.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_90.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_91.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_92.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_93.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_94.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_95.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_96.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_97.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_98.jpg
# ../Post_Event_Grids_In_JPEG\tile_8_99.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_0.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_1.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_10.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_100.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_101.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_102.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_103.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_104.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_105.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_106.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_107.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_108.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_109.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_11.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_110.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_111.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_112.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_113.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_114.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_115.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_116.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_117.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_118.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_119.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_12.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_120.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_121.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_122.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_123.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_124.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_125.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_126.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_127.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_128.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_129.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_13.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_130.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_131.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_132.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_133.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_134.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_135.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_136.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_137.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_138.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_139.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_14.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_140.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_141.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_142.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_143.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_144.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_15.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_16.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_17.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_18.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_19.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_2.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_20.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_21.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_22.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_23.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_24.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_25.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_26.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_27.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_28.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_29.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_3.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_30.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_31.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_32.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_33.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_34.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_35.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_36.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_37.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_38.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_39.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_4.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_40.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_41.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_42.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_43.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_44.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_45.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_46.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_47.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_48.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_49.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_5.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_50.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_51.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_52.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_53.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_54.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_55.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_56.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_57.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_58.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_59.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_6.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_60.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_61.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_62.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_63.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_64.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_65.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_66.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_67.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_68.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_69.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_7.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_70.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_71.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_72.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_73.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_74.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_75.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_76.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_77.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_78.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_79.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_8.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_80.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_81.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_82.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_83.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_84.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_85.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_86.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_87.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_88.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_89.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_9.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_90.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_91.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_92.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_93.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_94.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_95.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_96.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_97.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_98.jpg
# ../Post_Event_Grids_In_JPEG\tile_9_99.jpg
# Conversion from TIFF to JPEG completed.

# %% [markdown]
# ### Renaming the Files

# %% [markdown]
# <div align = "justify">For easier and more efficient data accessibility, it's necessary to rename the files in the directory. We'll use the function <b><i>rename_files</b></i> to accomplish this task of altering the file names in the given path.</div>

# %%
def rename_files(directory_path):
# Define the directory path where your files are located
    directory_path = directory_path
    
    # Get a list of all files in the directory
    files = os.listdir(directory_path)
    
    # Define a prefix for the new file names 
    # Change the prefix as per requirement
    prefix = "Post_Event_"
    
    # Start the numbering from 1
    number = 0
    
    # Loop through each file in the directory
    for filename in files:
        # Check if the item is a file (not a directory)
        if os.path.isfile(os.path.join(directory_path, filename)):
            # Get the file extension
            file_extension = os.path.splitext(filename)[1]
    
            # Create the new file name with leading zeros
            new_filename = f"{prefix}{number:03}{file_extension}"
    
            # Construct the full path to the original and new files
            old_filepath = os.path.join(directory_path, filename)
            new_filepath = os.path.join(directory_path, new_filename)
    
            # Rename the file
            os.rename(old_filepath, new_filepath)
    
            # Increment the number for the next file
            number += 1
    
    print("Files renamed successfully.")

# %%
rename_files(output_dir)
# Out:
# Files renamed successfully.

# %% [markdown]
# ### LabelMe

# %% [markdown]
# <div align = "justify">LabelMe is a renowned, open-source, graphical annotation tool perfect for annotating images and videos. The tool is Python-based and integrates Qt for its graphical interface. With its light nature and simple to use interface, LabelMe is a preferred option for an open-source visual annotation tool.</div><br>
#
# <div align="justify">LabelMe provides functionalities to facilitate annotations for object identification, semantic segmentation, and panoptic segmentation for both image and video data. Additionally, it also aids in addressing various computer vision issues like classification and segmentation. With LabelMe, users can create annotations using circles, rectangles (bounding boxes), lines, and polygons.</div><br>
#
#
#
# <div align="justify">Interested individuals can find the tool on GitHub, and a comprehensive, step-by-step guide for installing LabelMe can be found <a href="https://github.com/wkentaro/labelme">here</a>. If installation seems daunting or impossible due to system restrictions, LabelMe also provides standalone executive applications for Windows, MacOs, and Linux. Simply access the application <a href="https://github.com/wkentaro/labelme/releases/tag/v5.0.2">here</a> and run the executive file to get started.</div><br>
#
# <div align="justify">
# <h4>Drawing Annotations</h4> <ul> <li>Launch LabelMe and open the directory containing the images you aim to annotate. Opening a directory enables batch processing, which hastens the annotation process.</li> <li>Choose the image you wish to annotate from the file list located at the bottom right corner.</li> <li>Begin the annotation by choosing the 'Create Rectangle' option from the Edit menu. Click to set the rectangle starting point on the image and click on the next key point to form a rectangle. Continue this process until you've completed annotating the image, and click the starting keypoint to conclude the annotation.</li> <li>For different annotation formats, select 'Edit' from the title bar and choose the format you prefer.</li> <li>Indicate the annotation by typing in the label or selecting an option from the label list.</li> <li>By default LabelMe saves your annotation as a JSON file in the same folder as the images.For convenience, you can use the automatically-generated filename. For continuous save, select 'Save Automatically' in the File menu at the top left corner.</li> </ul></div>

# %% [markdown]
# <h4 style="color:rgb(195, 52, 235)"><strong>Tip 3</strong></h4>
# <div align="justify">Annotations are integral to the success of object recognition tasks. By labeling or annotating objects in a given set of images, you pinpoint to the model what to look for. Therefore, it is not only advisable but highly beneficial to annotate as many objects as possible.</div>

# %% [markdown]
# #### Naming convention of class label

# %% [markdown]
# <div align="justify"> Please ensure that you follow the following naming convention for the different objects, while labelling. If a different naming convention is followed, it might lead to error during submission on platform. </div>
#
# <table>
#   <tr>
#     <th>Object</th>
#     <th>Naming Convention</th>
#   </tr>
#   <tr>
#     <td>Undamaged Residential Building</td>
#     <td>undamagedresidentialbuilding</td>
#   </tr>
#   <tr>
#     <td>Damaged Residential Building</td>
#     <td>damagedresidentialbuilding</td>
#   </tr>
#    <tr>
#     <td>Undamaged Commercial Building</td>
#     <td>undamagedcommercialbuilding</td>
#   </tr>
#      <tr>
#     <td>Damaged Commercial Building</td>
#     <td>damagedcommercialbuilding</td>
#   </tr>
# </table>

# %% [markdown]
# <div align = "justify">After the annotation process, participants can move onto the task of building their models. YOLOv8, however, requires annotations to be in a distinct format. Therefore, the next step is to convert these annotations into the YOLOv8-required format. There are numerous utility scripts/packages designed to facilitate the conversion from .json to .txt files, which YOLOv8 requires. In this case, we have utilized the labelme2yolo package to transform the .json file into .txt format and also to generate the configuration file (dataset.yaml)</div>

# %% [markdown]
# Here we have annotated around 100 images of which 80 images will be used for training and the rest 20 as test set.

# %% [markdown]
# ### YOLO Annotations Format and Train Test Split
#
# <div align="justify">Since, YOLO algorithms requires the annotations to be in a specific format labels generated using LabelMe annotation tool should be exported to YOLO format with one *.txt file per image. If there are no objects in an image, no *.txt file is required. In case of bounding box annotations the *.txt file should be formatted with one row per object in class x_center y_center width height format. Box coordinates must be in normalized xywh format (from 0 to 1). If your boxes are in pixels, you should divide x_center and width by image width, and y_center and height by image height. Class numbers should be zero-indexed (start with 0).</div>

# %% [markdown]
# <div align = "justify">We have annotated 100 images using LabelMe and have converted them to .txt format using the <a href = https://pypi.org/project/labelme2yolo/>LabelMe2Yolo</a> package. We utilized the package to divide the data into training and testing sets, and also to create a .yaml file. By default, labelme2yolo package converts LabelMe annotations to <a href ="https://docs.ultralytics.com/datasets/obb/#yolo-obb-format"> YOLO OBB </a> format which has been used to build this model. The YOLO OBB format designates bounding boxes by their four corner points with coordinates normalized between 0 and 1. It follows this format: class_index, x1, y1, x2, y2, x3, y3, x4, y4. Internally, YOLO processes losses and outputs in the xywhr format, which represents the bounding box's center point (xy), width, height, and rotation. In order to get annotations in bounding box format  (x,y,w,h) you need to pass the parameter <i>--output_format bbox</i>. Participants could consider the approach of using standard bounding boxes, without any specific orientation, as a technique for improving their model.</div>

# %% [markdown]
# <div align = "justify">For more details on how to config the train and test validation split, please refer <a href = https://pypi.org/project/labelme2yolo/>LabelMe2Yolo</a>.By default 80% of the data is considered for Training Data and the rest of the 20% for the test data. Participants can modify this by changing the parameters.</div>

# %% [markdown]
# #### Generating Train and Test Data along with Configuration File

# %%
# !labelme2yolo --json_dir /path/to/labelme_json_dir/
# !labelme2yolo --json_dir ./Annotated_Data
# Out:
# INFO:labelme2yolo:Converting train set ...
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# INFO:labelme2yolo:Converting val set ...
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# INFO:labelme2yolo:Converting test set ...
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# INFO:labelme2yolo:Converting train set ...
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# INFO:labelme2yolo:Converting val set ...
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# INFO:labelme2yolo:Converting test set ...
#
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %% [markdown]
# ## Preparing the File Structure as required by YOLO
# <div align ="justify">The participants are required to construct the file structure as indicated below and adjust the dataset.yaml settings according to the file path provided.</div>

# %% [markdown]
# ### File Structure
# <div align="justify">YOLOv8, being a Deep Learning model for object detection, necessitates a specific directory framework for running effectively. The fundamental structure has a parent folder titled 'datasets', which further contains two subfolders: 'train', and 'val'.</div><br>
#
# <div align="justify">The 'datasets' folder: As the name indicates, this folder houses the complete data that YOLOv8 will be working on. It is pivotal as the model gains insight, verifies accuracy, and enhances its effectiveness using the data stored here.</div><br>
#
# <div align="justify">The 'train' subfolder: This is a subset of the datasets folder and houses a collection of both image files (.jpg format) and their corresponding annotation files (.txt format). The training data is used by the model to learn and create a mathematical function that can predict the output.</div><br>
#
# <div align="justify">The 'val' subfolder: Similarly, this contains the test images and their corresponding annotations. The test data is not learned by the model. Instead, it's used to evaluate the performance of the model's learning.</div><br>
#
# <div align="justify">The 'dataset.yaml' file: This is a vital document that encompasses critical details concerning the dataset and the manners of their use. It contains paths for training, testing, and their respective numbers of images, the total count of classes, and class labels. This is generated in the previous section - <b>YOLO Annotations Format and Train Test Split</b></div><br>

# %% [markdown]
# The files need to be organised in the following manner:
# <ul>
#     <li> dataset.yaml </li>
#     <li>datasets</li>
# <ul>
#     <li> train </li>
#     <ul>
#         <li>image1.jpg</li>
#         <li>image1.txt</li>
#         <li>image2.jpg</li>
#         <li>image2.txt</li>
#         <li>image3.jpg</li>
#         <li>image3.txt</li>
#     </ul>
#     <li> val</li>
#     <ul>
#         <li>image4.jpg</li>
#         <li>image4.txt</li>
#         <li>image5.jpg</li>
#         <li>image5.txt</li>
#         <li>image6.jpg</li>
#         <li>image6.txt</li>
#     </ul>
#
# </ul>

# %% [markdown]
# ## Model Building
# <div align="justify">
#
# Once the file structure is set up, we can proceed to the exercise of building the model. This process is iterative in nature, as participants have to keep experimenting and tweaking our model’s settings to improve its performance. Throughout this point, we continually assess the performance of our model using metric like mean average precission (mAP).</div>
#
# <div align="justify">Post-training, the model needs to be validated using a different dataset to further confirm that it works accurately when exposed to unseen data. Lastly, our model should also ensure it is not overfit or underfit. An overfit model implies it is too complex and may not work well with new data, while an underfit model implies the model misses the relevant relations between features and target outputs.</div><br>
#
# <div align="justify">Once we complete these steps, we will have a working model that we can now use for various predictions and interpretations.</div>

# %% [markdown]
# ### Model Training

# %% [markdown]
# <div align ="justify">Now that we have the data in a format appropriate for developing the model, we can begin training a model. In this demonstration notebook, we have used pre-trained object detection model from YOLOv8 developed by Ultralytics. This library offers a wide range of other models, each with the capacity for extensive parameter tuning and customization capabilities.</div>

# %% [markdown]
# <h4 style="color:rgb(195, 52, 235)"><strong>Tip 4</strong></h4>
# <div align ="justify">Ultralytics offers different object detection models which vary in size and the number of parameters it learns from the images. Participants can try the various models offered by Ultralytics to improve the accuracy of detection. For details regrading the different object detection models offered by Ultralytics please refer <a href = "https://docs.ultralytics.com/models/yolov8/">here.</a></div>

# %% [markdown]
# <h4 style="color:rgb(195, 52, 235)"><strong>Tip 5</strong></h4>
# <div align="justify">Here, we are using YOLOv8 (yolov8n.pt) to build a custom object detection model. Participants can explore other object detection models or come up with a totally different approach inorder to identify the damaged and undamaged buildings. </div>

# %%
#Loading the model
model = YOLO('yolov8n.pt')
# Display model information (optional)
model.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #Loading the model
# ----> 2 model = YOLO('yolov8n.pt')
#       3 # Display model information (optional)
#       4 model.info()
#
# NameError: name 'YOLO' is not defined

# %%
# Train the model on the dataset for 50 epochs
results = model.train(data='./dataset.yaml', epochs=50, imgsz=512)
# Out:
# New https://pypi.org/project/ultralytics/8.0.226 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.8.17 torch-2.1.0+cpu CPU (11th Gen Intel Core(TM) i7-1185G7 3.00GHz)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=./dataset.yaml, epochs=50, patience=50, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train2
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 225 layers, 3011628 parameters, 3011612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\detect\train2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning C:\Users\SX821KC\Final_Model_Training_Data\train... 80 images, 0 backgrounds, 0 corrupt: 100%|█████████
# train: New cache created: C:\Users\SX821KC\Final_Model_Training_Data\train.cache
# val: Scanning C:\Users\SX821KC\Final_Model_Training_Data\val... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2
# val: New cache created: C:\Users\SX821KC\Final_Model_Training_Data\val.cache
# Plotting labels to runs\detect\train2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 0 dataloader workers
# Logging results to runs\detect\train2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      2.069      4.188      1.709        364        512: 100%|██████████| 5/5 [00:44<00:00,  8.91
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332     0.0027      0.136     0.0022     0.0012
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.789      4.034      1.503        334        512: 100%|██████████| 5/5 [00:43<00:00,  8.66
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332    0.00353      0.176    0.00307    0.00144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G       1.66      3.588       1.37        385        512: 100%|██████████| 5/5 [00:40<00:00,  8.09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332    0.00401      0.124    0.00677    0.00239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.631      2.982        1.3        437        512: 100%|██████████| 5/5 [00:42<00:00,  8.53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332     0.0109      0.213     0.0281     0.0133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G      1.641      2.533      1.267        305        512: 100%|██████████| 5/5 [00:39<00:00,  7.97
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332     0.0246      0.389      0.127     0.0713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      1.608      2.219      1.253        340        512: 100%|██████████| 5/5 [00:41<00:00,  8.29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.914      0.115      0.164      0.092
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G      1.627      2.056      1.272        395        512: 100%|██████████| 5/5 [00:40<00:00,  8.01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.905       0.14      0.199      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G      1.549      1.949      1.258        291        512: 100%|██████████| 5/5 [00:44<00:00,  8.94
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.902       0.14      0.214      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G      1.558      1.914      1.215        425        512: 100%|██████████| 5/5 [00:43<00:00,  8.62
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332        0.7      0.191      0.237       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G      1.514      1.902      1.212        333        512: 100%|██████████| 5/5 [00:40<00:00,  8.12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.526      0.249      0.259      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G      1.533      1.796      1.191        431        512: 100%|██████████| 5/5 [00:44<00:00,  8.83
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.482      0.333      0.223      0.125
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G      1.528      1.747      1.192        504        512: 100%|██████████| 5/5 [00:41<00:00,  8.33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332       0.41      0.338      0.206      0.115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G      1.474      1.741      1.187        341        512: 100%|██████████| 5/5 [00:39<00:00,  7.81
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.452      0.244       0.21      0.117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G      1.505      1.659      1.167        405        512: 100%|██████████| 5/5 [00:39<00:00,  7.89
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.369       0.29      0.197      0.113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G      1.499      1.592      1.193        438        512: 100%|██████████| 5/5 [00:42<00:00,  8.41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.102      0.315      0.209      0.123
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G      1.454      1.671      1.176        417        512: 100%|██████████| 5/5 [00:41<00:00,  8.23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.203      0.349      0.224       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G      1.461      1.582        1.2        375        512: 100%|██████████| 5/5 [00:41<00:00,  8.22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.356      0.322       0.26       0.14
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G      1.422      1.619       1.18        386        512: 100%|██████████| 5/5 [00:38<00:00,  7.65
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.352      0.311      0.254      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G      1.411      1.639      1.181        368        512: 100%|██████████| 5/5 [00:39<00:00,  7.98
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.315      0.348      0.258      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G      1.417      1.532      1.179        373        512: 100%|██████████| 5/5 [00:38<00:00,  7.65
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.307      0.347      0.249      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G      1.412      1.585      1.168        364        512: 100%|██████████| 5/5 [00:41<00:00,  8.40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.281      0.322      0.245       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         0G      1.402      1.624      1.163        260        512: 100%|██████████| 5/5 [00:37<00:00,  7.53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.328      0.302      0.241      0.118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         0G      1.395      1.567      1.166        379        512: 100%|██████████| 5/5 [00:36<00:00,  7.34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.282      0.321      0.259      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50         0G      1.402      1.566       1.19        402        512: 100%|██████████| 5/5 [00:35<00:00,  7.07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.365      0.319      0.271      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50         0G      1.387      1.543      1.171        319        512: 100%|██████████| 5/5 [00:36<00:00,  7.25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.284       0.32      0.263      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50         0G      1.378      1.489      1.159        516        512: 100%|██████████| 5/5 [00:35<00:00,  7.18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.262      0.359       0.25      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50         0G      1.396      1.443      1.173        337        512: 100%|██████████| 5/5 [00:36<00:00,  7.21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.272       0.36      0.263      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50         0G      1.375      1.435      1.155        480        512: 100%|██████████| 5/5 [00:36<00:00,  7.25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.272      0.377      0.277      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50         0G      1.335      1.444      1.147        280        512: 100%|██████████| 5/5 [00:35<00:00,  7.05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.278       0.38      0.268      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50         0G      1.343      1.436      1.123        422        512: 100%|██████████| 5/5 [00:39<00:00,  7.82
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.272       0.42      0.269      0.152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50         0G      1.351      1.461      1.161        463        512: 100%|██████████| 5/5 [00:39<00:00,  7.95
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.285      0.443      0.274      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50         0G      1.344      1.481      1.148        408        512: 100%|██████████| 5/5 [00:36<00:00,  7.31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.288      0.377      0.286       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50         0G      1.335      1.433      1.128        361        512: 100%|██████████| 5/5 [00:42<00:00,  8.45
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.299      0.362      0.287      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G      1.342      1.387      1.135        412        512: 100%|██████████| 5/5 [00:36<00:00,  7.30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.275      0.417      0.294      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G      1.331      1.331      1.134        371        512: 100%|██████████| 5/5 [00:37<00:00,  7.58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.343      0.373      0.295      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G      1.305      1.374       1.11        390        512: 100%|██████████| 5/5 [00:38<00:00,  7.69
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.335      0.355      0.299       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G      1.285      1.319      1.094        542        512: 100%|██████████| 5/5 [00:35<00:00,  7.11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.312      0.396      0.312      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G       1.31      1.425      1.149        232        512: 100%|██████████| 5/5 [00:36<00:00,  7.27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.352      0.385      0.332      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G       1.35      1.423      1.148        351        512: 100%|██████████| 5/5 [00:39<00:00,  7.90
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332        0.3      0.442      0.343      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G       1.29      1.279      1.106        396        512: 100%|██████████| 5/5 [00:38<00:00,  7.61
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.338      0.405      0.345      0.199
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G      1.266      1.526      1.135        230        512: 100%|██████████| 5/5 [00:33<00:00,  6.80
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:06<0
#                    all         20        332      0.309      0.405      0.342      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G      1.281      1.479      1.144        313        512: 100%|██████████| 5/5 [00:38<00:00,  7.71
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.349      0.388      0.334      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G      1.217      1.323        1.1        209        512: 100%|██████████| 5/5 [00:33<00:00,  6.62
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.349      0.346      0.327      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G      1.226      1.359      1.144        251        512: 100%|██████████| 5/5 [00:32<00:00,  6.55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.437      0.305       0.32      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G      1.258      1.357      1.103        262        512: 100%|██████████| 5/5 [00:33<00:00,  6.70
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.416      0.322       0.32      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G      1.229      1.334      1.118        214        512: 100%|██████████| 5/5 [00:32<00:00,  6.56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.387      0.323      0.315      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G      1.221      1.306      1.116        255        512: 100%|██████████| 5/5 [00:32<00:00,  6.41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all         20        332      0.398      0.327      0.313      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G      1.231      1.278      1.124        246        512: 100%|██████████| 5/5 [00:36<00:00,  7.38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.365      0.361      0.307      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G      1.198      1.267       1.09        262        512: 100%|██████████| 5/5 [00:33<00:00,  6.67
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.355       0.37      0.308      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G      1.199      1.271       1.11        245        512: 100%|██████████| 5/5 [00:32<00:00,  6.58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all         20        332      0.353      0.382      0.302      0.183
#
# 50 epochs completed in 0.620 hours.
# Optimizer stripped from runs\detect\train2\weights\last.pt, 6.2MB
# Optimizer stripped from runs\detect\train2\weights\best.pt, 6.2MB
#
# Validating runs\detect\train2\weights\best.pt...
# Ultralytics YOLOv8.0.196  Python-3.8.17 torch-2.1.0+cpu CPU (11th Gen Intel Core(TM) i7-1185G7 3.00GHz)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<0
#                    all         20        332      0.298      0.439      0.344      0.207
# undamaged commercial building         20         32       0.31      0.406      0.291      0.162
# undamaged residential building         20        244        0.5      0.836      0.694      0.421
# damaged residential building         20         46      0.227      0.196      0.227      0.143
# damaged commercial building         20         10      0.157      0.317      0.164     0.0994
# Speed: 3.6ms preprocess, 140.6ms inference, 0.0ms loss, 17.8ms postprocess per image
# Results saved to runs\detect\train2

# %% [markdown]
# <b>Note: Participants, can find the model weights in runs\detect\ ....</b>

# %% [markdown]
# ## Model Evaluation
#
# <div align ="justify">Now that we have trained our model , all that is left is to evaluate it. For evaluation we will generate the mean average precission report. We will then plot the image results to visualise the results. When evaluating a machine learning model, it is essential to correctly and fairly evaluate the model's ability to generalize. This is because models have a tendency to overfit the dataset they are trained on. To estimate the in-sample and out-of-sample performance, we will see the results using the graph now.</div>

# %%
figure(figsize=(15, 10), dpi=80)
# reading the image 
results = img.imread('runs/detect/train2/results.png')   
# displaying the image 
plt.imshow(results)

# %% [markdown]
# <div align ="justify">From the above results we can see that we achieved an overall MAP-50 of 0.34 and the following MAP-50 on the various classes:
# <ul>
#     <li>Undamaged Commercial Building -0.29</li>
#     <li>Undamaged Residential Building -0.69</li>
#     <li>Damaged Residential Building - 0.23</li>
#     <li>Damaged Commercial Building -0.16</li>
# </ul>
# </div>

# %% [markdown]
# Let us now look at the confusion matrix, to better analyse the results:

# %%
figure(figsize=(20,15), dpi=80)  
# reading the image 
cf = img.imread('runs/detect/train2/confusion_matrix.png') 
# displaying the image 
plt.imshow(cf)

# %% [markdown]
# <div align ="justify">From the above, we see that the model is able to achieve overall mAP score of <b>0.34</b>. This is not a very good score, so your goal is to improve this score. Despite its decent performance in identifying undamaged residential buildings, with an mAP score of 0.69, the model struggles when it comes to detecting commercial buildings. Furthermore, the results highlight the inherent challenge in identifying damage in both residential and commercial structures.</div>

# %% [markdown]
# <h4 style="color:rgb(195, 52, 235)"><strong>Tip 6</strong></h4>

# %% [markdown]
# <div align = "justify">Participants have the opportunity to improve their model's performance by focusing on classes where the model's object detection is failing, and providing more labels for instances of that class. This could potentially enhance the mean average precision (mAP) score. Furthermore, creating synthetic data is another strategy participants could adopt to boost their results. This artificial data creation has the potential to enrich their model's learning experience and subsequently escalate its predictive performance. In addition, participants are encouraged to explore various other generative AI image models that have the ability to generate synthetic images. This strategy can enhance the training data quantity, which may subsequently result in improved outcomes.</div>

# %% [markdown]
# ## Submission

# %% [markdown]
# <div align = "justify">Once you are happy with your model, you can make a submission. To make a submission, you will need to use your model to make predictions on the images we have provided in the <b>"Data Description (Submission)"</b> section and upload the file onto the challenge platform.</div>

# %% [markdown]
# <div align="justify">Please ensure you do not alter the validation file names (.jpg format), prediction file names (.txt format), as well as do not insert spaces within class names in prediction files. If this is done, the submission process will not generate score on scorecard in platform.</div><br>
#
# Here is the format of the prediction of classes, which should be followed in prediction files (.txt format).<br>
# &lt;class_name&gt; &lt;confidence&gt; &lt;left&gt; &lt;top&gt; &lt;right&gt; &lt;bottom&gt;
#
# For example:
#
# undamagedresidentialbuilding 0.8850483894348145 91.77708435058594 9.232025146484375 135.427978515625 61.545249938964844
#
# damagedresidentialbuilding 0.39302119612693787 417.7862243652344 72.88447570800781 490.5438537597656 124.75260925292969

# %% [markdown]
# ### Download submission images from platform

# %% [markdown]
# Participants need to download the images from the submission section of the challenge portal.

# %%
def unzip_folder(zip_filepath, dest_dir):
    with zipfile.ZipFile(zip_filepath, 'r') as zip_ref:
        zip_ref.extractall(dest_dir)
    print(f'The zip file {zip_filepath} has been extracted to the directory {dest_dir}')



submission_zip = './challenge_1_submission_images.zip'
submission_directory = './challenge_1_submission_images'
unzip_folder(submission_zip,submission_directory)
# Out:
# The zip file ./challenge_1_submission_images.zip has been extracted to the directory ./challenge_1_submission_images

# %% [markdown]
# ### Making Predictions on the Submission Data

# %%
# Load the Model
model = YOLO('./best.pt')

# %%
# Decoding according to the .yaml file class names order
decoding_of_predictions ={0: 'undamagedcommercialbuilding', 1: 'undamagedresidentialbuilding', 2: 'damagedresidentialbuilding', 3: 'damagedcommercialbuilding'}

directory = 'challenge_1_submission_images/Validation_Data_JPEG'
# Directory to store outputs
results_directory = 'Validation_Data_Results'

# Create submission directory if it doesn't exist
if not os.path.exists(results_directory):
    os.makedirs(results_directory)

# Loop through each file in the directory
for filename in os.listdir(directory):
    # Check if the current object is a file and ends with .jpeg
    if os.path.isfile(os.path.join(directory, filename)) and filename.lower().endswith('.jpg'):
        # Perform operations on the file
        file_path = os.path.join(directory, filename)
        print(file_path)
        print("Making a prediction on ", filename)
        results = model.predict(file_path, save=True, iou=0.5, save_txt=True, conf=0.25)
        
        for r in results:
            conf_list = r.boxes.conf.numpy().tolist()
            clss_list = r.boxes.cls.numpy().tolist()
            original_list = clss_list
            updated_list = []
            for element in original_list:
                 updated_list.append(decoding_of_predictions[int(element)])

        bounding_boxes = r.boxes.xyxy.numpy()
        confidences = conf_list
        class_names = updated_list

        # Check if bounding boxes, confidences and class names match
        if len(bounding_boxes) != len(confidences) or len(bounding_boxes) != len(class_names):
            print("Error: Number of bounding boxes, confidences, and class names should be the same.")
            continue
        text_file_name = os.path.splitext(filename)[0]
        # Creating a new .txt file for each image in the submission_directory
        with open(os.path.join(results_directory, f"{text_file_name}.txt"), "w") as file:
            for i in range(len(bounding_boxes)):
                # Get coordinates of each bounding box
                left, top, right, bottom = bounding_boxes[i]
                # Write content to file in desired format
                file.write(f"{class_names[i]} {confidences[i]} {left} {top} {right} {bottom}\n")
        print("Output files generated successfully.")
# Out:
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_012.jpg
# Making a prediction on  Post_Event_012.jpg
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_012.jpg: 512x512 22 undamaged residential buildings, 2 damaged residential buildings, 121.4ms
# Speed: 0.0ms preprocess, 121.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 1 label saved to runs\detect\predict2\labels
#
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_013.jpg: 512x512 6 undamaged residential buildings, 91.1ms
# Speed: 2.0ms preprocess, 91.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 2 labels saved to runs\detect\predict2\labels
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_013.jpg
# Making a prediction on  Post_Event_013.jpg
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_014.jpg
# Making a prediction on  Post_Event_014.jpg
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_014.jpg: 512x512 9 undamaged residential buildings, 4 damaged residential buildings, 100.7ms
# Speed: 0.0ms preprocess, 100.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 3 labels saved to runs\detect\predict2\labels
#
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_015.jpg: 512x512 8 undamaged residential buildings, 111.0ms
# Speed: 0.0ms preprocess, 111.0ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 4 labels saved to runs\detect\predict2\labels
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_015.jpg
# Making a prediction on  Post_Event_015.jpg
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_016.jpg
# Making a prediction on  Post_Event_016.jpg
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_016.jpg: 512x512 28 undamaged residential buildings, 178.6ms
# Speed: 5.1ms preprocess, 178.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 5 labels saved to runs\detect\predict2\labels
#
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_017.jpg: 512x512 1 undamaged commercial building, 20 undamaged residential buildings, 92.7ms
# Speed: 0.0ms preprocess, 92.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 6 labels saved to runs\detect\predict2\labels
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_017.jpg
# Making a prediction on  Post_Event_017.jpg
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_018.jpg
# Making a prediction on  Post_Event_018.jpg
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_018.jpg: 512x512 1 undamaged commercial building, 20 undamaged residential buildings, 1 damaged residential building, 108.4ms
# Speed: 0.0ms preprocess, 108.4ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 7 labels saved to runs\detect\predict2\labels
#
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_019.jpg: 512x512 9 undamaged residential buildings, 139.1ms
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_019.jpg
# Making a prediction on  Post_Event_019.jpg
# Speed: 1.5ms preprocess, 139.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 8 labels saved to runs\detect\predict2\labels
#
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_020.jpg: 512x512 1 undamaged commercial building, 13 undamaged residential buildings, 134.0ms
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_020.jpg
# Making a prediction on  Post_Event_020.jpg
# Speed: 1.7ms preprocess, 134.0ms inference, 2.8ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 9 labels saved to runs\detect\predict2\labels
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_021.jpg
# Making a prediction on  Post_Event_021.jpg
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_021.jpg: 512x512 2 undamaged commercial buildings, 9 undamaged residential buildings, 254.7ms
# Speed: 24.4ms preprocess, 254.7ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 10 labels saved to runs\detect\predict2\labels
#
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_022.jpg: 512x512 1 undamaged commercial building, 8 undamaged residential buildings, 100.5ms
# Speed: 2.0ms preprocess, 100.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 11 labels saved to runs\detect\predict2\labels
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_022.jpg
# Making a prediction on  Post_Event_022.jpg
# Output file generated successfully.
# challenge_1_submission_images/Validation_Data_JPEG\Post_Event_023.jpg
# Making a prediction on  Post_Event_023.jpg
# image 1/1 C:\Users\SX821KC\challenge_1_submission_images\Validation_Data_JPEG\Post_Event_023.jpg: 512x512 2 undamaged commercial buildings, 18 undamaged residential buildings, 109.5ms
# Speed: 1.2ms preprocess, 109.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict2
# 12 labels saved to runs\detect\predict2\labels
# Output file generated successfully.

# %% [markdown]
# <b>Note: The submission file should contain only the .txt files and not the images.</b>

# %%
# Define your source directory and the destination where the zip file will be created
source_dir = results_directory
destination_zip = 'submission'

# Create a zip file from the directory
shutil.make_archive(destination_zip, 'zip', source_dir)

print(f"Directory {source_dir} has been successfully zipped into {destination_zip}.")
# Out:
# Directory Validation_Data_Results has been successfully zipped into submission.

# %% [markdown]
# ### Upload submission file on platform.

# %% [markdown]
# Upload the submission.zip on the <a href ="https://challenge.ey.com">platform</a> to get score generated on scoreboard.

# %% [markdown]
# ## Conclusion
#
# <div align ="justify">Now that you have learned a basic approach to model training, it’s time to try your own approach! Feel free to modify any of the functions presented in this notebook. We look forward to seeing your version of the model and the results. Best of luck with the challenge!</div>
